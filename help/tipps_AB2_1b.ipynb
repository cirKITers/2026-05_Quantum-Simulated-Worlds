# %% [markdown]
# # Tipps für Aufgabe 1b) des Arbeitsblattes 2

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Das Hadamard-Gatter erzeugt eine Superposition:</p>
#
#
#   - $|0\rangle \rightarrow \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle) = |+\rangle$
#   - $|1\rangle \rightarrow \frac{1}{\sqrt{2}}(|0\rangle - |1\rangle) = |-\rangle$
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Das Ergebnis liegt auf der x-Achse der Bloch-Sphäre.</p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Musterlösung</h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   qc = QuantumCircuit(1)
# qc.h(0)
# state = Statevector.from_instruction(qc)
#   ```
# </details>
# </div>
