# %% [markdown]
# # Zusatzaufgabe zu Aufgabe 1b) des Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Komplexe Amplituden </h2>
#   <p>Erstelle einen Qubit-Zustand mit komplexen Amplituden und analysiere seine Eigenschaften:</p>
#
#   1. Erstelle den Zustand $|\psi\rangle = \frac{1}{\sqrt{2}}|0\rangle + \frac{i}{\sqrt{2}}|1\rangle$
#   2. Berechne die Norm des Zustands
#   3. Berechne die Wahrscheinlichkeiten für eine Messung
#   4. Bestimme die Bloch-Sphäre-Koordinaten ($\theta$ und $\phi$)
#   5. Visualisiere den Zustand mit Qiskit auf der Bloch-Sphäre
#   </ol>
# </div>

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

# Erstelle den Zustand |ψ⟩ = (1/√2)|0⟩ + (i/√2)|1⟩
# Dein Code hier:


# Berechne die Norm
# Dein Code hier:


# Berechne die Wahrscheinlichkeiten
# Dein Code hier:


# Bestimme θ und φ
# Tipp: cos(θ/2) = Amplitude von |0⟩, e^(iφ) * sin(θ/2) = Amplitude von |1⟩
# Dein Code hier:


# Visualisiere auf der Bloch-Sphäre
# Dein Code hier:
