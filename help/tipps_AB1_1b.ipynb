# %% [markdown]
# # Tipps für die Aufgabe 1b) des Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die Norm eines Vektors berechnest du mit <code>np.linalg.norm()</code>.</p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Auf die einzelnen Komponenten des Vektors kannst du per Index zugreifen:
#     <ul>
#         <li>Amplitude für $|0\rangle$: <code>ket_plus[0]</code></li>
#         <li>Amplitude für $|1\rangle$: <code>ket_plus[1]</code></li>
#     </ul>
#     </p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 3 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die Wahrscheinlichkeit ist das Quadrat des Betrags (Absolutbetrag) der Amplitude:</p>
#
#   ```python
#   prob_0 = abs(ket_plus[0])**2
#   prob_1 = abs(ket_plus[1])**2
#   ```
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 4 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die Summe der Wahrscheinlichkeiten sollte 1 ergeben (normierter Zustand).</p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Lösung </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   norm = np.linalg.norm(ket_plus)
# prob_0 = abs(ket_plus[0])**2
# prob_1 = abs(ket_plus[1])**2
# # Ergebnis: norm=1.0, prob_0=0.5, prob_1=0.5
#   ```
# </details>
# </div>
