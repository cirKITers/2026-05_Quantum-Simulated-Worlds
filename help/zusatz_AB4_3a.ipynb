# %% [markdown]
# # Zusatzaufgabe zu Aufgabe 3a) des Arbeitsblattes 4

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Komplexere Orakel </h2>
#   Erstelle ein Orakel mit 4 Qubits:
#   <ol>
#     <li>Implementiere ein Orakel, das die Parität von 4 Bits berechnet</li>
#     <li>Teste mit dem Deutsch-Jozsa Algorithmus</li>
#     <li>Vergleiche mit der klassischen Lösung</li>
#   </ol>
# </div>

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

def deutsch_jozsa_4qubit(oracle_qc):
    """Deutsch-Jozsa mit 4 Qubits"""
    qc = QuantumCircuit(5, 4)  # 4 Eingabe + 1 Ausgabe
    
    # H-Gates auf alle Eingabe-Qubits
    # Dein Code hier:

    # Hilfs-Qubit initialisieren
    # Dein Code hier:
    
    # Orakel hinzufügen
    # Dein Code hier:
    
    # H-Gate auf erstes Qubit
    # Dein Code hier:
    
    # Messen
    qc.measure(range(4), range(4))
    
    simulator = AerSimulator()
    job = simulator.run(qc, shots=100)
    return job.result().get_counts()

# Erstelle ein Paritäts-Orakel
def parity_oracle_4():
    """Paritäts-Orakel für 4 Qubits"""
    qc = QuantumCircuit(5)
    # Dein Code: CNOT von jedem Eingangs-Qubit zum Ausgangs-Qubit
    return qc

oracle = parity_oracle_4()
print("Paritäts-Orakel:")
print(oracle.draw())

result = deutsch_jozsa_4qubit(oracle)
print(f"\nErgebnis: {result}")
