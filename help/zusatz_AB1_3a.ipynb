# %% [markdown]
# # Zusatzaufgabe zu Aufgabe 3a) des Arbeitsblattes 1
#
# Wenn du deine regulären Aufgaben bereits erledigt hast und dich weiter vertiefen möchtest, dann sind diese Aufgaben genau richtig für dich.

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Globale Phase </h2>
#   <p>Untersuche den Effekt der globalen Phase:</p>
#
#   1. Erstelle zwei Zustände: $|\psi_1\rangle = |+\rangle$ und $|\psi_2\rangle = e^{i\pi/4}|+\rangle$
#   2. Vergleiche die Bloch-Sphäre-Darstellungen beider Zustände
#   3. Erkläre, warum die globale Phase keine physikalische Bedeutung hat
#   4. Erstelle einen Zustand mit relativer Phase und erkläre den Unterschied
# </div>

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector


# Erstelle |ψ₁⟩ = |+⟩
qc1 = QuantumCircuit(1)
qc1.h(0)
state1 = Statevector.from_instruction(qc1)

# Erstelle |ψ₂⟩ = e^(iπ/4) * |+⟩ (globale Phase)
# Dein Code hier:


# Vergleiche die Bloch-Sphäre-Darstellungen
print("Zustand 1 (|+⟩):")
display(plot_bloch_multivector(state1))

print("Zustand 2 (e^(iπ/4)|+⟩):")
# Dein Code hier:


# Erstelle einen Zustand mit relativer Phase: (|0⟩ + i|1⟩)/√2
# Dein Code hier:


# Erklärung:
# Deine Antwort hier:
