# %% [markdown]
# # Zusatzaufgaben zu Aufgaben 3b) des Arbeitsblattes 5

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Mehrere Lösungen </h2>
#   Erweitere Grover für mehrere gesuchte Lösungen:
#   <ol>
#     <li>Erstelle ein Orakel, das zwei Zustände markiert</li>
#     <li>Implementiere den Grover-Algorithmus</li>
#     <li>Untersuche, wie sich die Erfolgsrate ändert</li>
#   </ol>
# </div>

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

def grover_oracle_multi(ziele):
    """Orakel für mehrere gesuchte Zustände"""
    n = len(ziele[0])
    qc = QuantumCircuit(n)
    
    # Dein Code: Markiere jeden Zielzustand
    for ziel in ziele:
        pass
    
    return qc

# Teste mit zwei Zielen
ziele = ["101", "110"]
oracle = grover_oracle_multi(ziele)
print(f"Orakel für {ziele}:")
print(oracle.draw() if oracle else "Leer")

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Optimaler Winkel </h2>
#   Untersuche den optimalen Winkel für Grover:
#   <ol>
#     <li>Implementiere Grover mit variablen Iterationen</li>
#     <li>Plotte die Erfolgsrate gegen die Iterationen</li>
#     <li>Finde das Optimum</li>
#   </ol>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dein Code: Teste verschiedene Iterationszahlen
def test_iterationen(ziel, n_qubits, max_iterationen):
    """Testet verschiedene Iterationszahlen"""
    ergebnisse = []
    
    for i in range(1, max_iterationen + 1):
        # Dein Code: Führe Grover mit i Iterationen durch
        # Messe die Erfolgsrate
        pass
    
    return ergebnisse

# Plotten
# Dein Code: plt.plot()
# Dein Code: plt.show()

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Amplituden-Verstärkung </h2>
#   Visualisiere die Amplituden während der Iteration:
#   <ol>
#     <li>Erstelle eine Funktion, die die Amplituden plotten kann</li>
#     <li>Zeige, wie sich die Amplituden ändern</li>
#     <li>Erkläre das Ergebnis</li>
#   </ol>
# </div>

# %%
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt

def plot_amplituden(ziel, n_qubits):
    """Plot die Amplituden nach jeder Iteration"""
    # Dein Code: Erstelle Schaltkreis und führe Iteration durch
    # Extrahiere die Amplituden
    # Plotte die Amplituden
    pass

# Teste
# Dein Code: plot_amplituden("101", 3)
