# %% [markdown]
# # Tipps zu Aufgabe 1c) des Arbeitsblattes 3

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Um nur ein Qubit zu messen:
#
#   ```python
#   qc = QuantumCircuit(2, 1)  # 2 Qubits, 1 klassisches Bit
#   # Bell State erstellen
#
#   # Nur Qubit 0 messen
#   qc.measure(0, 0)
#   ```
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Ergebnis: Du wirst sehen, dass Qubit 0 mit 50% Wahrscheinlichkeit 0 und 50% Wahrscheinlichkeit 1 ist - aber wenn du Qubit 1 auch messen würdest, wären die Ergebnisse immer korreliert!
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-check" style="font-size:36px"></i> &nbsp; Musterlösung </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   qc = QuantumCircuit(2, 1)
#   qc.h(0)
#   qc.cx(0, 1)
#   qc.measure(0, 0)
#   # Ergebnis: 50% 0, 50% 1
#   ```
# </details>
# </div>
