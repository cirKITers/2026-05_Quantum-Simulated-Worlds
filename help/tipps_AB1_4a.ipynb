# %% [markdown]
# # Tipps zu Aufgabe 4a) des Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die verschiedenen Gates in Qiskit:</p>
#     <ul>
#     <li><code>qc.h(0)</code> - Hadamard Gate</li>
#     <li><code>qc.x(0)</code> - Pauli-X Gate (NOT)</li>
#     <li><code>qc.y(0)</code> - Pauli-Y Gate</li>
#     <li><code>qc.z(0)</code> - Pauli-Z Gate</li>
#     <li><code>qc.s(0)</code> - S-Gate (Phase)</li>
#     <li><code>qc.t(0)</code> - T-Gate (Tofoli)</li>
#     </ul>
#     <p>Probiere verschiedene Kombinationen aus!</p>
# </details>
# </div>
