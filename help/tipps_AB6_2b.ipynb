# %% [markdown]
# # Tipps zu Aufgabe 2b) des Arbeitsblattes 6

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Benutze die Funktionen `zug(feld, x, y)`, `alle_aus(feld)` aus Aufgabe 1a) und `combo_zu_koordinaten(combo)` aus Aufgabe 1b).
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Denke daran mit einer Kopie des Feldes zu arbeiten und die Kopie bei jedem Zug zu überschreiben. Nur so siehst du, wie alle Züge auf das gesamte Feld wirken und kannst sicherstellen, dass bei der nächsten Combo wieder das "korrekte" Feld genutzt wird.
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Musterlösung </h2>
#   <details>
#   <summary>Hier klicken!</summary>
#
# ```python
# def klassische_loesung(feld):
#     """Löst das Problem klassisch"""
#     # Alle möglichen Kombinationen von Zügen (9 mögliche Klicks bei 3x3 Feld)
#
#     for combo in product([0, 1], repeat=9):
#         kopie = [row[:] for row in feld]  # Kopie erstellen
#         for x, y in combo_zu_koordinaten(combo):
#             kopie = zug(kopie, x, y)
#         if alle_aus(kopie):
#             return combo
#
#     return None  # Keine Lösung gefunden
#   ```
#
#   </details>
# </div>
