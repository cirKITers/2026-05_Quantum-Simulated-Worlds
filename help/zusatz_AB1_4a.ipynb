# %% [markdown]
# # Zusatzaufgabe zu Aufgabe 4a) des Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Herausforderung - Zustandsvektoren auf der Bloch-Sphäre </h2>
#   <p>Fortgeschrittene Aufgabe für Experten:</p>
#   <ol>
#     <li>Erstelle eine Funktion, die einen zufälligen Punkt auf der Bloch-Sphäre generiert</li>
#     <li>Erstelle den entsprechenden Qubit-Zustand</li>
#     <li>Visualisiere den Zustand</li>
#     <li>Erkläre, warum jeder Punkt auf der Bloch-Sphäre einem möglichen Qubit-Zustand entspricht</li>
#   </ol>
# </div>

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

def random_bloch_state():
    """Generiert einen zufälligen Qubit-Zustand auf der Bloch-Sphäre"""
    # Wähle zufällige Winkel
    # Dein Code hier:
    
    # Berechne Amplituden
    # Dein Code hier:
    
    return np.array([alpha, beta]), theta, phi

# Teste die Funktion
state_vector, theta, phi = random_bloch_state()
print(f"Zufälliger Zustand: {state_vector}")
print(f"Winkel: θ={theta:.4f}, φ={phi:.4f}")
print(f"Norm: {np.linalg.norm(state_vector)}")

# Visualisiere den Zustand
# Dein Code hier:


# Erklärung:
# Jeder Punkt auf der Bloch-Sphäre entspricht einem reinen Qubit-Zustand.
# Die Bloch-Sphäre ist eine geometrische Darstellung aller möglichen Qubit-Zustände.
# Die Pole entsprechen den Basiszuständen |0⟩ und |1⟩.
# Punkte auf dem Äquator entsprechen Superpositionen mit gleicher Wahrscheinlichkeit.
# Die Winkel θ und φ parametrisieren den Zustand eindeutig (bis auf globale Phase).
