# %%
# Hier nichts ändern, nur ausführen!
# %matplotlib inline
import sys; sys.path.append("../code"); from setup_AB1 import *; setup_erfolg();

# %% [markdown]
# # 🎮 Interaktives Bloch‑Sphere‑Widget für Arbeitsblatt 1
#
# Hier kannst du die Winkel $\theta$ und $\phi$ per Slider ändern und sofort das zugehörige Bloch‑Diagramm sehen.

# %%
show_bloch()
