# %% [markdown]
# # Tipps für die Aufgabe 1a) des Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Um einen Vektor in NumPy zu erstellen, verwendest du <code>np.array([...])</code>.</p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Lösung für |0⟩</h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   ket_0 = np.array([1, 0])
#   ```
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Lösung für |1⟩</h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   ket_1 = np.array([0, 1])
#   ```
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Lösung für |+⟩</h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   ket_plus = np.array([1/np.sqrt(2), 1/np.sqrt(2)])
#   ```
# </details>
# </div>
