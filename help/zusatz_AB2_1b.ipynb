# %% [markdown]
# # Zusatzaufgaben zu Aufgabe 1b) des Arbeitsblattes 2

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Gate-Sequenzen </h2>
#   Untersuche die Wirkung von Gate-Sequenzen:
#   <ol>
#     <li>Erstelle eine Sequenz: H-X-H</li>
#     <li>Erstelle eine Sequenz: X-H-X</li>
#     <li>Vergleiche die Ergebnisse auf der Bloch-Sphäre</li>
#     <li>Erkläre das Ergebnis</li>
#   </ol>
# </div>

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

# Sequenz 1: H-X-H
qc1 = QuantumCircuit(1)
# Dein Code hier:


state1 = Statevector.from_instruction(qc1)
print("Sequenz H-X-H:")
display(plot_bloch_multivector(state1))

# Sequenz 2: X-H-X
qc2 = QuantumCircuit(1)
# Dein Code hier:


state2 = Statevector.from_instruction(qc2)
print("Sequenz X-H-X:")
display(plot_bloch_multivector(state2))

# Erklärung:
# Deine Antwort hier:
