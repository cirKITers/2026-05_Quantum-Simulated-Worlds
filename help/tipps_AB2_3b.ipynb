# %% [markdown]
# # Tipps zu Aufgabe 3b) des Arbeitsblattes 2

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Nicht alle Gatter kommutieren (sind vertauschbar)!</p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp;  Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   - X und H: <strong>nicht kommutativ</strong> - X gefolgt von H ≠ H gefolgt von X
#   - X und X: kommutativ - X gefolgt von X = Identität
#   - Z und Z: kommutativ
#
# </details>
# </div>
