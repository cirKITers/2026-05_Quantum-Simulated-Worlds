# %% [markdown]
# # Zusatzaufgaben zu Aufgabe 1a) des Arbeitsblattes 2

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Gate-Matrizen </h2>
#   Untersuche die mathematische Darstellung der Quantengatter:
#
#   1. Gib die Matrixdarstellung von X, Y, Z, H Gate an
#   2. Überprüfe, dass diese Matrizen unitär sind ($U \cdot U^\dagger = I$)
#   3. Berechne das Produkt zweier Gate-Matrizen
#   4. Erkläre, warum Quantengatter durch unitäre Matrizen dargestellt werden
#   </ol>
# </div>

# %%
import numpy as np
from qiskit.quantum_info import Operator

# Pauli-X (NOT) Gate
X = Operator.from_label('X')
print("X-Gate Matrix:")
print(X.to_matrix())

# Pauli-Y Gate
# Dein Code hier:


# Pauli-Z Gate
# Dein Code hier:


# Hadamard Gate
# Dein Code hier:


# Überprüfe Unitarität: U * U^dagger sollte I sein
# Du kannst U^dagger mit U.adjoint() berechnen
# Multiplikation von Matrizen: A @ B
# Dein Code hier:
