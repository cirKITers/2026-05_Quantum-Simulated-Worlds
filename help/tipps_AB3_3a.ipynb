# %% [markdown]
# # Tipps zu Aufgabe 3a) des Arbeitsblattes 3

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Ein Zustand ist verschränkt, wenn:</p>
#     <ul>
#     <li>Die Messergebnisse korreliert sind</li>
#     <li>Der Zustand nicht als Produkt einzelner Qubit-Zustände geschrieben werden kann</li>
#     </ul>
#
#   Beispiel: $|\phi^+\rangle = \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$ kann NICHT geschrieben werden als $|\psi_1\rangle \otimes |\psi_2\rangle$
#
# </details>
# </div>
