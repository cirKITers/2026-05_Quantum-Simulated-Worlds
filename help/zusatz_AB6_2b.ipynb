# %% [markdown]
# # Zusatzaufgabe zu Aufgabe 2b) des Arbeitsblattes 6

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> Optimiert die klassische Lösung </h2>
#
#   Überlegt euch, ob ihr einen Algorithmus findet, mit dem ihr nicht alle Möglichkeiten nacheinander durchprobieren müsst.
#
#   - Wie viele Versuche brauchst du?
#   - Wie viel schneller kannst du werden im Vergleich zur Brute-Force-Lösung?
# </div>

# %%
# Kopiere deinen Code aus Aufgabe 2b) und verändere die Funktion klassische_loesung
# Denke auch daran, die Hilfsfunktionen aus Aufgabe 2a) zu kopieren
