# %% [markdown]
# # Tipps zu Aufgabe 2a) des Arbeitsblattes 3

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Der GHZ-Zustand ist eine Verallgemeinerung des Bell States auf 3 Qubits:</p>
#
#   $|GHZ\rangle = \frac{1}{\sqrt{2}}(|000\rangle + |111\rangle)$
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Du kannst mit dem $|\phi^+\rangle$ Status beginnen und ein weiteres CNOT-Gate nutzen
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-check" style="font-size:36px"></i> &nbsp; Musterlösung </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   qc_ghz = QuantumCircuit(3)
#   qc_ghz.h(0)
#   qc_ghz.cx(0, 1)
#   qc_ghz.cx(1, 2)
#   ```
#
#   oder auch
#
#   ```python
#   qc_ghz = QuantumCircuit(3)
#   qc_ghz.h(0)
#   qc_ghz.cx(0, 1)
#   qc_ghz.cx(0, 2)
#   ```
# </details>
# </div>
