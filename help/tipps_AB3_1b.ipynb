# %% [markdown]
# # Tipps zu Aufgabe 1b) des Arbeitsblattes 3

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 1 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Bei $|\phi^+\rangle$ sind die Ergebnisse immer gleich: 00 oder 11.
#
#   Bei $|\psi^+\rangle$ sind die Ergebnisse immer ungleich: 01 oder 10.
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 2 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   Ein X-Gate vor dem H-Gate erzeugt einen anderen Bell State.
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 3 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die vier Bell States werden durch unterschiedliche Gate-Sequenzen erstellt</p>
#
#   - $|\phi^+\rangle$: H(0), CNOT(0,1)
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 4 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die vier Bell States werden durch unterschiedliche Gate-Sequenzen erstellt</p>
#
#   - $|\phi^-\rangle$: X(0), H(0), CNOT(0,1)
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 5 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die vier Bell States werden durch unterschiedliche Gate-Sequenzen erstellt</p>
#
#   - $|\psi^+\rangle$: H(0), CNOT(0,1), X(1)</li>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tipp 6 </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#     <p>Die vier Bell States werden durch unterschiedliche Gate-Sequenzen erstellt</p>
#
#   - $|\psi^-\rangle$: X(0), H(0), CNOT(0,1), X(1)</li>
#
#   <p>Alternativ kannst du auch Z oder Y Gates verwenden!</p>
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-check" style="font-size:36px"></i> &nbsp; Musterlösung </h2>
#     <details>
#     <summary>Hier klicken!</summary>
#
#   ```python
#   # |Φ⁺⟩:
#   qc_phi_plus.h(0)
#   qc_phi_plus.cx(0, 1)
#
#   # |Φ⁻⟩:
#   qc_phi_minus.x(0)
#   qc_phi_minus.h(0)
#   qc_phi_minus.cx(0, 1)
#
#   # |Ψ⁺⟩:
#   qc_psi_plus.h(0)
#   qc_psi_plus.cx(0, 1)
#   qc_psi_plus.x(1)
#
#   # |Ψ⁻⟩:
#   qc_psi_minus.x(0)
#   qc_psi_minus.h(0)
#   qc_psi_minus.cx(0, 1)
#   qc_psi_minus.x(1)
#   ```
# </details>
# </div>
