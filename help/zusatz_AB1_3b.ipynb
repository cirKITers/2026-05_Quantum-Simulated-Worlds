# %% [markdown]
# # Zusatzaufgabe zu Aufgabe 3b) des  Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp; Simulation von Messungen </h2>
#   <p>Vertiefte Analyse von Messungen und Wahrscheinlichkeiten:</p>
#
#   1. Erstelle einen Zustand mit Amplituden (0.6, 0.8)
#   2. Führe 10000 Messungen durch und vergleiche mit der theoretischen Vorhersage
#   3. Erstelle ein Histogramm der Ergebnisse
#   4. Berechne den Fehler zwischen Theorie und Simulation
#   </ol>
# </div>

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# Erstelle einen Zustand mit Amplituden (0.6, 0.8)
# Hinweis: Die Amplituden müssen normiert sein!
# Dein Code hier:


# Theoretische Wahrscheinlichkeiten
# Dein Code hier:


# Erstelle und führe den Schaltkreis aus
# Dein Code hier:


# Vergleiche Theorie und Simulation
# Dein Code hier:


# Berechne den Fehler
# Dein Code hier:
